# %% [markdown]
# # **Active Learning Parte 2 - YOLOv8**
# **Tutorial seguido de**: [Import Pre-annotated images to Label-Studio](https://labelstud.io/blog/tutorial-importing-local-yolo-pre-annotated-images-to-label-studio/)
#
# **Paso 1.**
# - Crear el siguiente directorio: `C:\\yolo\\datasets`.
# - Adentro colocar una carpeta con el nombre de tu dataset. Por convención se trabaja con 'one' aunque se puede poner el nombre que se desee. De forma que la ruta de la carpeta es la siguinete: `c:\yolo\datasets\one` o `c:\yolo\datasets\hemileia`, etc.
# - Dentro de `one` crear las carpetas `images`, `labels`, junto con un archivo que se llame `classes.txt`. De forma que dentro de `one` existan 2 carpetas y 1 archivo .txt.
# - Dentro del archivo `classes.txt` colocar simplemente el nombre de clase etiquetada (sin absolutamente nada más). Por ejemplo, si tu clase se llama "Hemeleia", escribir: Hemeleia
#
#
# **Paso 2.**
# En Conda prompt:
# * Cargar el ambiente de Label Studio empleado `conda activate`.
# * Escribir las siguinetes dos líneas:
#     * set LABEL_STUDIO_LOCAL_FILES_SERVING_ENABLED=true
#     * set LABEL_STUDIO_LOCAL_FILES_DOCUMENT_ROOT=C:\\yolo\\datasets
#
# **Paso 3.**
# * Abrir LabelStudio
# * Crear un proyecto sin ninguna Label Interface.
# * En *Add Source Storage* poner el path absoluto `c:\yolo\datasets\one\images`. Notar que si en lugar de `one` se empleó otro nombre, habrá que colocar ese nuevo nombre. Por ejemplo: `c:\yolo\datasets\hemileia\images`.
# * Presionar en *Add*, luego en *Sync*. *Nota: probablemente aparezca como *Failed*. Es normal*.
# * Cerrar LabelStudio con `crtl+c`
#
# **Paso 4.**
# * Colocar dentro de `images` las imágenes de tu dataset.
# * Colocar dentro de `labels` las etiquetas .txt.
# * Emplear el siguiente código con el fin de hacer una correcciones a los archivos txt dentro de labels.:

# %%
import os

# Directorio que contiene los archivos .txt con las etiquetas
labels_dir = r"C:\yolo\datasets\hemileia_predicted\labels" # Colocar la ruta correcta de labels <----

# Función para eliminar el último valor decimal en cada línea y guardar en el mismo archivo
def remove_last_value(labels_dir):
    for file_name in os.listdir(labels_dir):
        if file_name.endswith(".txt"):
            file_path = os.path.join(labels_dir, file_name)
            
            with open(file_path, 'r') as file:
                lines = file.readlines()
            
            new_lines = []
            for line in lines:
                parts = line.strip().split()
                if len(parts) == 6:  # Asegurarse de que haya 6 valores en la línea
                    parts = parts[:5]  # Eliminar el último valor
                new_lines.append(' '.join(parts) + '\n')
            
            with open(file_path, 'w') as file:
                file.writelines(new_lines)
            print(f"Updated labels in {file_path}")

# Eliminar el último valor decimal en cada línea de los archivos en el directorio
remove_last_value(labels_dir)
# Out:
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium14.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium143.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium145.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium147.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium148.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium152.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium153.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium175.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium178.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium190.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium206.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium219.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium222.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium223.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium226.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium228.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium250.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium269.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium270.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium271.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium300.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium31.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium314.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium315.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium316.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium319.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium327.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium336.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium338.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium341.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium344.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium351.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium352.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium353.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium354.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium358.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium363.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium370.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium401.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium416.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium42.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium424.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium445(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium446(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium447(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium448(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium449(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium45(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium450(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium472(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium472.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium473(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium473.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium474(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium474.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium476(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium477(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium478(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium479(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium48(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium48.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium480(1).txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium482.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium483.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium484.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium485.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium487.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium488.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium489.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium49.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium493.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium494.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium495.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium496.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium497.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium499.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium5.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium500.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium501.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium502.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium503.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium504.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium506.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium507.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium508.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium509.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium511.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium512.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium515.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium516.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium518.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium52.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium520.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium521.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium522.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium524.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium526.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium527.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium528.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium529.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium531.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium532.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium533.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium538.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium539.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium54.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium543.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium544.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium545.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium546.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium548.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium549.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium55.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium550.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium551.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium552.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium553.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium554.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium555.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium556.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium557.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium56.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium560.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium561.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium563.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium568.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium57.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium570.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium571.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium572.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium573.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium575.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium576.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium577.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium578.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium58.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium580.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium583.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium586.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium588.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium589.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium590.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium592.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium594.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium596.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium599.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium6.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium60.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium600.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium601.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium604.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium607.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium609.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium61.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium610.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium611.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium612.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium614.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium616.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium618.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium619.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium620.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium621.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium622.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium623.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium625.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium626.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium629.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium63.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium630.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium632.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium633.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium634.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium635.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium638.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium639.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium64.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium641.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium642.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium646.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium648.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium652.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium654.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium655.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium656.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium657.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium658.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium660.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium662.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium664.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium666.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium667.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium668.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium669.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium670.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium671.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium672.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium673.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium676.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium677.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium679.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium68.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium680.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium681.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium683.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium684.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium687.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium688.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium689.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium691.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium693.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium694.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium697.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium698.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium699.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium7.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium70.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium700.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium702.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium703.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium704.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium705.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium707.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium708.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium709.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium71.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium710.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium711.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium712.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium713.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium714.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium715.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium716.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium717.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium72.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium720.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium721.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium724.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium725.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium727.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium728.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium729.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium730.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium732.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium734.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium735.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium736.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium739.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium74.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium740.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium741.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium742.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium744.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium745.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium746.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium747.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium749.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium750.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium751.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium753.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium754.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium755.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium756.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium76.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium760.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium761.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium762.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium763.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium765.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium766.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium768.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium769.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium77.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium770.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium776.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium777.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium78.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium781.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium783.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium786.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium787.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium788.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium79.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium790.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium792.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium793.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium794.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium795.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium796.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium799.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium8.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium80.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium801.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium802.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium804.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium805.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium806.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium81.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium813.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium814.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium815.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium817.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium818.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium819.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium82.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium820.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium822.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium824.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium826.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium827.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium828.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium829.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium83.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium830.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium831.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium832.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium833.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium835.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium838.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium839.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium84.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium841.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium842.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium844.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium845.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium847.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium848.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium851.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium852.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium855.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium856.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium858.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium859.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium86.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium860.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium861.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium862.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium863.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium864.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium865.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium866.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium867.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium868.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium87.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium871.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium873.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium874.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium875.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium876.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium877.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium878.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium88.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium881.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium882.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium883.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium884.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium886.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium887.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium888.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium889.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium89.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium891.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium892.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium893.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium895.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium896.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium898.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium899.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium9.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium90.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium901.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium902.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium904.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium905.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium906.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium907.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium908.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium91.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium910.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium912.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium913.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium916.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium917.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium918.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium919.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium92.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium921.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium922.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium923.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium924.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium927.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium928.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium929.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium93.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium932.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium94.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium95.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium96.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium97.txt
# Updated labels in C:\yolo\datasets\hemileia_predicted\labels\Cronartium99.txt

# %% [markdown]
# **Paso 5.**
# * En conda prompt escribir lo siguiente:
# * label-studio-converter import yolo -i /yolo/datasets/one -o output.json --image-root-url "/data/local-files/?d=one/images"
#
# *Nota: cambiar `one` por el nombre de tu carpeta del dataset.*
#
# El código anterior generará un archivo `.json` guardado en la ruta de tu ambiente, es decir, en conda prompt aparece la siguinete ruta al escribir un comando:
# `([nombre_de_tu_ambiente]) C:\users\[usuario]:`. Tu archivo se guardará en dicha ruta.
#
# **Paso 6.**
# * Abrir nuevamente LabelStudio.
# * En el proyecto que se creó importar el archivo `.json` creado.
# * Ir a `settings`, luego a `label Interface`.
# * En `code` escribir lo siguiente:

# %%
#Formato xml:
"""

<View>
  <RectangleLabels name="label" toName="image">
    <Label value="Hemelia" background="green"/>
  </RectangleLabels>

  <Image name="image" value="$image"/>
</View>


"""
# Out:
# '\n\n<View>\n  <RectangleLabels name="label" toName="image">\n    <Label value="Hemelia" background="green"/>\n  </RectangleLabels>\n\n  <Image name="image" value="$image"/>\n</View>\n\n\n'

# %% [markdown]
# *Notar que `value:""` debe ser reemplazado por el valor que se empleó en el archivo `classes.txt`*

# %% [markdown]
# Archivo .yaml:
#
# names:
# - Avena
# - I.Lacumosa
# - Malva_Porviflora
# - Xhantium
# - Aegylops
# - P.Convolvulus
# - Heredacea
# - Qualium_Aparine
# - Ambrosia
# - Otra
# nc: 10
# train: train
# val: valid
# pr

# %% [markdown]
# ---
# Luego del active learning se dividrán 352 elementos.

# %%
import os
import shutil
import random

# Define las rutas
base_path = r"C:\Users\AlxMa\Downloads\project-18-at-2024-06-16-13-17-33563881"
images_path = os.path.join(base_path, "images")
labels_path = os.path.join(base_path, "labels")

# Ruta para los nuevos datasets
datasets_path = os.path.join(base_path, "datasets")
train_images_path = os.path.join(datasets_path, "train", "images")
train_labels_path = os.path.join(datasets_path, "train", "labels")
valid_images_path = os.path.join(datasets_path, "valid", "images")
valid_labels_path = os.path.join(datasets_path, "valid", "labels")

# Crear las carpetas si no existen
os.makedirs(train_images_path, exist_ok=True)
os.makedirs(train_labels_path, exist_ok=True)
os.makedirs(valid_images_path, exist_ok=True)
os.makedirs(valid_labels_path, exist_ok=True)

# Obtener lista de archivos
image_files = os.listdir(images_path)
label_files = os.listdir(labels_path)

# Asegurarse de que las listas de archivos coincidan
image_files.sort()
label_files.sort()

# Comprobar si las listas de imágenes y etiquetas tienen el mismo número de archivos
if len(image_files) != len(label_files):
    print("El número de imágenes y etiquetas no coincide.")
else:
    # Emparejar archivos de imágenes y etiquetas
    paired_files = list(zip(image_files, label_files))

    # Mezclar los archivos
    random.shuffle(paired_files)

    # Calcular el índice de división
    split_index = int(len(paired_files) * 0.8)

    # Dividir los archivos en entrenamiento y validación
    train_files = paired_files[:split_index]
    valid_files = paired_files[split_index:]

    # Función para mover archivos
    def move_files(file_pairs, dest_images_path, dest_labels_path):
        for img_file, lbl_file in file_pairs:
            shutil.move(os.path.join(images_path, img_file), os.path.join(dest_images_path, img_file))
            shutil.move(os.path.join(labels_path, lbl_file), os.path.join(dest_labels_path, lbl_file))

    # Mover archivos de entrenamiento
    move_files(train_files, train_images_path, train_labels_path)

    # Mover archivos de validación
    move_files(valid_files, valid_images_path, valid_labels_path)

    print("División completada. Archivos movidos a las carpetas correspondientes.")
# Out:
# División completada. Archivos movidos a las carpetas correspondientes.

# %% [markdown]
# Crear carpeta "to_pred" con las imágenes restantes del dataset

# %%
import os
import shutil

# Definir las rutas
hemileia_images_path = r"C:\yolo\datasets\hemileia_predicted\images" # Ruta donde se encuentran todas las imágenes
datasets_path = r"C:\Users\AlxMa\Downloads\project-18-at-2024-06-16-13-17-33563881\datasets" # Ruta donde se encuentran las imágenes de  prueba y entranmeinto 
train_images_path = os.path.join(datasets_path, "train", "images")
valid_images_path = os.path.join(datasets_path, "valid", "images")
to_pred_path = os.path.join(datasets_path, "to_pred")

# Crear la carpeta to_pred si no existe
os.makedirs(to_pred_path, exist_ok=True)

# Obtener lista de archivos en train y valid
train_files = os.listdir(train_images_path)
valid_files = os.listdir(valid_images_path)

# Crear un set con los nombres de archivos en train y valid para una búsqueda rápida
existing_files = set(train_files + valid_files)

# Obtener lista de archivos en hemileia/images
hemileia_files = os.listdir(hemileia_images_path)

# Copiar archivos que no estén en existing_files a la carpeta to_pred
for file in hemileia_files:
    if file not in existing_files:
        src_file = os.path.join(hemileia_images_path, file)
        dest_file = os.path.join(to_pred_path, file)
        shutil.copy(src_file, dest_file)
        print(f"Copiado: {file}")

print("Proceso completado. Archivos copiados a la carpeta to_pred.")
# Out:
# Copiado: Cronartium530.jpg
# Copiado: Cronartium534.jpg
# Copiado: Cronartium535.jpg
# Copiado: Cronartium536.jpg
# Copiado: Cronartium537.jpg
# Copiado: Cronartium540.jpg
# Copiado: Cronartium541.jpg
# Copiado: Cronartium542.jpg
# Copiado: Cronartium547.jpg
# Copiado: Cronartium558.jpg
# Copiado: Cronartium559.jpg
# Copiado: Cronartium562.jpg
# Copiado: Cronartium564.jpg
# Copiado: Cronartium565.jpg
# Copiado: Cronartium566.jpg
# Copiado: Cronartium567.jpg
# Copiado: Cronartium569.jpg
# Copiado: Cronartium574.jpg
# Copiado: Cronartium579.jpg
# Copiado: Cronartium581.jpg
# Copiado: Cronartium582.jpg
# Copiado: Cronartium584.jpg
# Copiado: Cronartium585.jpg
# Copiado: Cronartium587.jpg
# Copiado: Cronartium59.jpg
# Copiado: Cronartium591.jpg
# Copiado: Cronartium593.jpg
# Copiado: Cronartium595.jpg
# Copiado: Cronartium597.jpg
# Copiado: Cronartium598.jpg
# Copiado: Cronartium602.jpg
# Copiado: Cronartium603.jpg
# Copiado: Cronartium605.jpg
# Copiado: Cronartium606.jpg
# Copiado: Cronartium608.jpg
# Copiado: Cronartium613.jpg
# Copiado: Cronartium615.jpg
# Copiado: Cronartium617.jpg
# Copiado: Cronartium62.jpg
# Copiado: Cronartium624.jpg
# Copiado: Cronartium627.jpg
# Copiado: Cronartium628.jpg
# Copiado: Cronartium631.jpg
# Copiado: Cronartium636.jpg
# Copiado: Cronartium637.jpg
# Copiado: Cronartium640.jpg
# Copiado: Cronartium643.jpg
# Copiado: Cronartium644.jpg
# Copiado: Cronartium645.jpg
# Copiado: Cronartium647.jpg
# Copiado: Cronartium649.jpg
# Copiado: Cronartium65.jpg
# Copiado: Cronartium650.jpg
# Copiado: Cronartium651.jpg
# Copiado: Cronartium653.jpg
# Copiado: Cronartium659.jpg
# Copiado: Cronartium66.jpg
# Copiado: Cronartium661.jpg
# Copiado: Cronartium663.jpg
# Copiado: Cronartium665.jpg
# Copiado: Cronartium67.jpg
# Copiado: Cronartium674.jpg
# Copiado: Cronartium675.jpg
# Copiado: Cronartium678.jpg
# Copiado: Cronartium682.jpg
# Copiado: Cronartium685.jpg
# Copiado: Cronartium686.jpg
# Copiado: Cronartium69.jpg
# Copiado: Cronartium690.jpg
# Copiado: Cronartium692.jpg
# Copiado: Cronartium695.jpg
# Copiado: Cronartium696.jpg
# Copiado: Cronartium701.jpg
# Copiado: Cronartium706.jpg
# Copiado: Cronartium718.jpg
# Copiado: Cronartium719.jpg
# Copiado: Cronartium722.jpg
# Copiado: Cronartium723.jpg
# Copiado: Cronartium726.jpg
# Copiado: Cronartium73.jpg
# Copiado: Cronartium731.jpg
# Copiado: Cronartium733.jpg
# Copiado: Cronartium737.jpg
# Copiado: Cronartium738.jpg
# Copiado: Cronartium743.jpg
# Copiado: Cronartium748.jpg
# Copiado: Cronartium75.jpg
# Copiado: Cronartium752.jpg
# Copiado: Cronartium757.jpg
# Copiado: Cronartium758.jpg
# Copiado: Cronartium759.jpg
# Copiado: Cronartium764.jpg
# Copiado: Cronartium767.jpg
# Copiado: Cronartium771.jpg
# Copiado: Cronartium772.jpg
# Copiado: Cronartium773.jpg
# Copiado: Cronartium774.jpg
# Copiado: Cronartium775.jpg
# Copiado: Cronartium778.jpg
# Copiado: Cronartium779.jpg
# Copiado: Cronartium780.jpg
# Copiado: Cronartium782.jpg
# Copiado: Cronartium784.jpg
# Copiado: Cronartium785.jpg
# Copiado: Cronartium789.jpg
# Copiado: Cronartium791.jpg
# Copiado: Cronartium797.jpg
# Copiado: Cronartium798.jpg
# Copiado: Cronartium800.jpg
# Copiado: Cronartium803.jpg
# Copiado: Cronartium807.jpg
# Copiado: Cronartium808.jpg
# Copiado: Cronartium809.jpg
# Copiado: Cronartium810.jpg
# Copiado: Cronartium811.jpg
# Copiado: Cronartium812.jpg
# Copiado: Cronartium816.jpg
# Copiado: Cronartium821.jpg
# Copiado: Cronartium823.jpg
# Copiado: Cronartium825.jpg
# Copiado: Cronartium834.jpg
# Copiado: Cronartium836.jpg
# Copiado: Cronartium837.jpg
# Copiado: Cronartium840.jpg
# Copiado: Cronartium843.jpg
# Copiado: Cronartium846.jpg
# Copiado: Cronartium849.jpg
# Copiado: Cronartium85.jpg
# Copiado: Cronartium850.jpg
# Copiado: Cronartium853.jpg
# Copiado: Cronartium854.jpg
# Copiado: Cronartium857.jpg
# Copiado: Cronartium869.jpg
# Copiado: Cronartium870.jpg
# Copiado: Cronartium872.jpg
# Copiado: Cronartium879.jpg
# Copiado: Cronartium880.jpg
# Copiado: Cronartium885.jpg
# Copiado: Cronartium890.jpg
# Copiado: Cronartium894.jpg
# Copiado: Cronartium897.jpg
# Copiado: Cronartium900.jpg
# Copiado: Cronartium903.jpg
# Copiado: Cronartium909.jpg
# Copiado: Cronartium911.jpg
# Copiado: Cronartium914.jpg
# Copiado: Cronartium915.jpg
# Copiado: Cronartium920.jpg
# Copiado: Cronartium925.jpg
# Copiado: Cronartium926.jpg
# Copiado: Cronartium930.jpg
# Copiado: Cronartium931.jpg
# Copiado: Cronartium933.jpg
# Copiado: Cronartium98.jpg
# Proceso completado. Archivos copiados a la carpeta to_pred.

# %% [markdown]
# Verificar que todas las eituqetas sean la misma:

# %%
import os

# Definir la ruta a la carpeta de etiquetas
labels_path = r"C:\Users\AlxMa\Desktop\hemileia\labels"

# Función para cambiar todas las etiquetas a '0'
def set_labels_to_zero(labels_path):
    label_files = os.listdir(labels_path)
    for lbl_file in label_files:
        lbl_file_path = os.path.join(labels_path, lbl_file)
        with open(lbl_file_path, 'r') as file:
            lines = file.readlines()
        with open(lbl_file_path, 'w') as file:
            for line in lines:
                parts = line.strip().split()
                if len(parts) > 0:
                    parts[0] = '0'  # Cambiar la etiqueta a '0'
                    file.write(' '.join(parts) + '\n')

# Cambiar todas las etiquetas a '0' en la carpeta especificada
set_labels_to_zero(labels_path)
print("Todas las etiquetas se han cambiado a '0'.")
# Out:
# Todas las etiquetas se han cambiado a '0'.

# %% [markdown]
# ---
# Cambiar nombre a hemileia

# %%
import os

# Ruta de la carpeta principal
ruta_carpeta_principal = r"C:\Users\AlxMa\Desktop\hemileia"

# Subcarpetas donde se encuentran los archivos
subcarpetas = ["images", "labels"]

# Iterar sobre las subcarpetas
for subcarpeta in subcarpetas:
    # Ruta completa de la subcarpeta
    ruta_subcarpeta = os.path.join(ruta_carpeta_principal, subcarpeta)
    # Listar todos los archivos en la subcarpeta
    archivos = os.listdir(ruta_subcarpeta)
    
    # Iterar sobre los archivos
    for archivo in archivos:
        # Comprobar si el archivo es un .jpg o .txt
        if archivo.endswith('.jpg') or archivo.endswith('.txt'):
            # Crear el nuevo nombre del archivo
            nuevo_nombre = archivo.replace('Cronartium', 'hemileia')
            # Obtener la ruta completa del archivo original y del nuevo archivo
            ruta_original = os.path.join(ruta_subcarpeta, archivo)
            ruta_nueva = os.path.join(ruta_subcarpeta, nuevo_nombre)
            # Renombrar el archivo
            os.rename(ruta_original, ruta_nueva)

print("Renombrado de archivos completado.")
# Out:
# Renombrado de archivos completado.
